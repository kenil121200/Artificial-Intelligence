# %% [markdown]
# <a href="https://colab.research.google.com/github/kenil121200/Artificial-Intelligence/blob/master/Assignment_1_AI_LAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #SIGMOID ACTIVATION FUNCTION
# ![1.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import math 
  
x = np.linspace(-10, 10,100) 
z = 1/(1 + np.exp(-x)) 
  
plt.plot(x, z) 
plt.xlabel("x") 
plt.ylabel("Sigmoid(X)") 
  
plt.show()

# %% [markdown]
# #ReLU
#
#
# **f(x)=max(0,x)**

# %%
x = np.linspace(-10, 10, 1000)
y = np.maximum(0, x)

plt.figure(figsize=(10, 5))
plt.plot(x, y)
plt.legend(['Relu'])
plt.show()

# %% [markdown]
# #Leaky ReLU function
#
# 𝑓(α,𝑥) = α𝑥 𝑓𝑜𝑟 𝑥<0; 𝑓(𝑎,𝑥) = 𝑥 𝑓𝑜𝑟 𝑥>=0, where α is a small constant.

# %%
def leakyrelu(x, alpha=0.01): 
 if (x>0):
  return np.maximum(0, x)
 else:
  return x*alpha

y = [leakyrelu(i, alpha=0.1) for i in x]
plt.axvline(x=0, color="red", linewidth=.5)
plt.axhline(y=0, color="red", linewidth=.5)
plt.plot(x, y)
plt.show()

# %% [markdown]
# #Tanh (hyperbolic tangent)
#
# ![image.png](data:image/png;base64,...)

# %%
x = np.linspace(-10, 10, 1000)
y = ( 2 / (1 + np.exp(-2*x) ) ) -1

plt.figure(figsize=(10, 5))
plt.plot(x, y)
plt.legend(['hyperbolic tangent'])
plt.show()

# %% [markdown]
# #Exponential Linear  Unit
#
# ![image.png](data:image/png;base64,...)

# %%
def elu(arr, alpha):
    a = []
    for x in arr:
        if x >= 0:
            a.append(x)
        else:
            a.append(alpha * (np.exp(x)-1))
    return a

X = np.linspace(-5, 5, 200)
elu1 = elu(X, 1.0)

plt.plot(X, elu1)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('ELU')
plt.show()
